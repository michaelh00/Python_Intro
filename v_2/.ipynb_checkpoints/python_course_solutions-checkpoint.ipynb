# %% [markdown]
# ## Exercise Block 1 — Variables and operators
#
# Work in the empty cell below. Do the **Core** set first; try **Stretch**
# if you have time; **Challenge** is a hard optional one — no shame in
# skipping it.
#
# ### Core
#
# 1. Create three variables describing a country: `name` (str),
#    `population_millions` (float), and WTO membership (bool).
# 2. Print a sentence using all three, shaped like
#    `"Kenya has 55.1 million people. Is it member of the WTO? True"`.
#    Use `print()` with commas.
# 3. A document has 142 pages. Using `//` and `%`, compute full chapters of
#    20 pages, and leftover pages. Print both.
# 4. Given `year_signed = 1994`, compute `age` in 2026. Print it.
#
# ### Stretch (optional)
#
# 1. Given `tariff_rate = 7.5` and `discount = 0.20`, print the discounted
#    rate with a message.
# 2. Check whether `population_millions` is between 10 and 100 inclusive.
#    Store in `is_medium_sized`. Print.
# 3. Deliberately trigger a `TypeError`. Read the traceback. Fix it.
#
# ### Challenge (hard, optional)
#
# Given exactly `total_seconds = 100000`, print the duration as
# `"1 day, 3 hours, 46 minutes, 40 seconds"` using only `//` and `%` — no
# imports, no libraries. You'll need to peel off days, then hours, then
# minutes, then seconds, in that order.

# %% [markdown]
# ## Exercise Block 1 — Solutions

# %%
# Core 1 & 2
name = "Germany"
population_millions = 83.24
member_wto = True
print(name, "has", population_millions, "people. Is it member of the WTO?", member_wto)
# Out:
# Germany has 83.24 people. Is it member of the WTO? True

# %%
# Core 3
doc_size = 142
chapter_size = 20
num_chapters = doc_size // chapter_size
pages_left = doc_size % chapter_size
print("Number of chapters:", num_chapters)
print("Pages left:", pages_left)
# Out:
# Number of chapters: 7
# Pages left: 2

# %%
# Core 4
year_signed = 1994
age = 2024 - year_signed
print("Age since signing:", age)
# Out:
# Age since signing: 30

# %%
# Stretch 1
tariff_rate = 7.5
discount = 0.2
discounted_tariff_rate = tariff_rate * (1 - discount)
print("Discounted tariff rate:", discounted_tariff_rate)
# Out:
# Discounted tariff rate: 6.0

# %%
# Stretch 2
population_millions = 83.24
is_medium_sized = population_millions > 10 and population_millions < 100
print("Population between 10 and 100 millions:", is_medium_sized)
# Out:
# Population between 10 and 100 millions: True

# %%
# Challenge

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 2 — Strings and containers
#
# Use the empty cell below.
#
# ### Core
#
# 1. Clean `raw = "  KENYA - Tariff Schedule 2024.CSV  "` into
#    `"kenya_-_tariff_schedule_2024.csv"` by chaining methods.
# 2. Build a list `un_founders` (≥ 4 countries). Print first, last, length.
# 3. From `symbol = "WT-DS316-AB-R"`, slice out `"DS316"`.
# 4. Make a dict with `name`, `capital`, `population_millions`. Print a
#    sentence with an f-string.
#
# ### Stretch
#
# 1. From `rates = [1.8, 12.0, 13.5, 4.3, 7.5, 9.0, 5.5]`, slice the last
#    three and the middle three.
# 2. Add `"is_wto_member": True` to your dict, print it, then bump the
#    population by 1.0 and print again.
# 3. Build a `set` from `rates`. Print how many are distinct.
#
# ### Challenge (hard, optional)
#
# 1. From `raw = "population: 55.1 million"`, extract `55.1` as a float
#    using slicing only.

# %% [markdown]
# ## Exercise Block 2 — Solutions

# %%
# Core 1
raw = "  KENYA - Tariff Schedule 2024.CSV  "
cleaned = raw.strip().lower().replace(" ", "_")
cleaned
# Out:
# 'kenya_-_tariff_schedule_2024.csv'

# %%
# Core 2
un_founders = ["United States", "Sowjet Union", "United Kingdom", "France", "China"]
print(un_founders[0])
print(un_founders[-1])
print(len(un_founders))
# Out:
# United States
# China
# 5

# %%
# Core 3
symbol = "WT-DS316-AB-R"
symbol[3:8]
# Out:
# 'DS316'

# %%
# Core 4
d = {"name": "Brazil", "capital": "Brasília", "population_millions": 213}
print(f"{d['name']} has a population of {d['population_millions']} million and its capital is {d['capital']}.")
# Out:
# Brazil has a population of 213 million and its capital is Brasília.

# %%
# Stretch 1
rates = [1.8, 12.0, 13.5, 4.3, 7.5, 9.0, 5.5]
print(rates[-3:])
print(rates[2:5])
# Out:
# [7.5, 9.0, 5.5]
# [13.5, 4.3, 7.5]

# %%
# Stretch 2
d["is_wto_member"] = True
print(d)
d["population_millions"] = d["population_millions"] + 1
print(d)
# Out:
# {'name': 'Brazil', 'capital': 'Brasília', 'population_millions': 213, 'is_wto_member': True}
# {'name': 'Brazil', 'capital': 'Brasília', 'population_millions': 214, 'is_wto_member': True}

# %%
# Stretch 3
distinct_rates = set(rates)
print(len(distinct_rates))
# Out:
# 7

# %%
# Challenge 1
raw = "population: 55.1 million"
str_55 = raw[12:17]
float_55 = float(str_55)
print(float_55)
print(type(float_55))
# Out:
# 55.1
# <class 'float'>

# %%
# Challenge 2

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 3 — Decisions, loops, functions
#
# Use this data (run it first), then work in the empty cell below it.
#
# ### Core
#
# 1. Loop and print each country's name.
# 2. Loop and print `"<name>: high tariff"` only for `avg_tariff > 10`.
# 3. Write `is_populous(country, threshold=50)` returning a bool. Test twice.
# 4. Count WTO members with a `for` + `if`. Print the count.
#
# ### Stretch
#
# 1. Build `wto_only`, a list of only the WTO-member dicts. Print its length.
# 2. Write `tariff_category(rate)` returning `"low"`, `"moderate"`,
#    `"high"`, or `"very high"`, and print `"<name>: <category>"` per country.
#
# ### Challenge (hard, optional)
#
# Write `top_n_by_tariff(countries, n=3)` that returns the names of the `n`
# countries with the highest `avg_tariff`, in descending order — **without**
# using `sorted`. Do it manually: on each pass, scan a working copy for the
# current maximum, record its name, remove it, repeat `n` times.

# %%
countries = [
    {"name": "Switzerland", "population_millions": 8.8,   "avg_tariff": 1.8,  "wto_member": True},
    {"name": "Kenya",       "population_millions": 55.1,  "avg_tariff": 12.0, "wto_member": True},
    {"name": "Brazil",      "population_millions": 214.3, "avg_tariff": 13.5, "wto_member": True},
    {"name": "Japan",       "population_millions": 125.7, "avg_tariff": 4.3,  "wto_member": True},
    {"name": "Argentina",   "population_millions": 45.4,  "avg_tariff": 13.6, "wto_member": True},
    {"name": "Iran",        "population_millions": 88.6,  "avg_tariff": 20.1, "wto_member": False},
]

# %% [markdown]
# ## Exercise Block 3 — Solutions

# %%
# Core 1
for c in countries:
    print(c["name"])
# Out:
# Switzerland
# Kenya
# Brazil
# Japan
# Argentina
# Iran

# %%
# Core 2
for c in countries:
    country_tariff = c["avg_tariff"]
    if country_tariff > 10:
        print(f"{c['name']}: high tariff")
# Out:
# Kenya: high tariff
# Brazil: high tariff
# Argentina: high tariff
# Iran: high tariff

# %%
# Core 3
def is_populous(contry, threshold=50):
    if contry["population_millions"] > threshold:
        return True
    else:
        return False
print(is_populous(countries[0]))
print(is_populous(countries[2]))
# Out:
# False
# True

# %%
# Core 4
wto_member = 0
for country in countries:
    if country["wto_member"] == True:
        wto_member = wto_member + 1
print(wto_member)
# Out:
# 5

# %%
# Stretch 1
wto_only = []
for country in countries:
    if country["wto_member"] == True:
        wto_only.append(country)
print(len(wto_only))
# Out:
# 5

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 4 — Exploring the folder
#
# Run the setup cell below first so `data_dir` and `files` exist, then work
# in the empty cell.
#
# ### Core
#
# 1. Print the total number of files using `iterdir()` and a counter (not
#    `len(files)` — practise the loop).
# 2. Print the `.stem` of each file whose `.suffix` is `.txt`.
# 3. Count how many filenames contain `"DS"` (case-insensitive). Print it.
# 4. Using `.glob(...)`, list the `.name` of every `.csv`, one per line.
#
# ### Stretch
#
# 1. Build `counts_by_suffix` mapping each suffix to its file count. Print it.
# 2. Build `probably_renamed`: filenames that do **not** start with `WT-`,
#    `G_`, or `TN_`. Print the length and first three.
# 3. Print the longest filename (by `len(f.name)`) and its length.
#
# ### Challenge (hard, optional)
#
# Write `filter_by(files, contains=None, suffix=None)` that returns only the
# `Path` objects whose name contains `contains` (if given) **and** whose
# suffix equals `suffix` (if given). Both default to `None`, meaning "ignore
# this filter". Test it three ways: `suffix=".txt"` alone, `contains="ds"`
# alone, and both together.

# %% [markdown]
# ## Exercise Block 4 — Solutions

# %%
# Core 1
from pathlib import Path
data_dir = Path("sample_data")

counter = 0
for file in data_dir.iterdir():
    counter = counter + 1
print(f"Total number of files: {counter}.")
# Out:
# Total number of files: 24.

# %%
# Core 2
for file in data_dir.iterdir():
    if file.suffix == ".txt":
        print(file.stem)
# Out:
# AB_2019_7_footwear_import
# ab_report_ds135_asbestos
# Agreement_on_Safeguards
# Copy of Copy of report
# ds379_china_auto_parts_panel
# ds58_shrimp_turtle_AB
# final_final_v2
# GATT_1994_consolidated
# notes_meeting_march
# panel report DS412 Canada FIT programme
# report(draft)v2
# scan0001
# TN_MA_W_103
# Understanding_DSU_consolidated_1994
# untitled_document_3
# WT-DS135-R_asbestos
# WT-DS316-AB-R
# WT-DS58-AB-R_shrimp_turtle
# WT-MIN11-W-2
# wt_min17_w_8

# %%
# Core 3
counter = 0
for file in data_dir.iterdir():
    if "ds" in file.name.lower():
        print(file)
        counter = counter + 1
print(f"Files containing DS: {counter}.")
# Out:
# sample_data\ab_report_ds135_asbestos.txt
# sample_data\Agreement_on_Safeguards.txt
# sample_data\ds379_china_auto_parts_panel.txt
# sample_data\ds58_shrimp_turtle_AB.txt
# sample_data\panel report DS412 Canada FIT programme.txt
# sample_data\Understanding_DSU_consolidated_1994.txt
# sample_data\WT-DS135-R_asbestos.txt
# sample_data\WT-DS316-AB-R.txt
# sample_data\WT-DS58-AB-R_shrimp_turtle.txt
# Files containing DS: 9.

# %%
# Core 4
csvs = list(data_dir.glob("*.csv"))
for csv in csvs:
    print(csv.name)
# Out:
# Costa Rica - Tariff Schedule (revised) FINAL v3.csv
# G_MA_TAR_RS_45_Japan.csv
# G_MA_TAR_RS_70_Argentina.csv
# tariff_schedule_brazil_2021.csv

# %%
# Stretch 1
probably_renamed = []
for file in data_dir.iterdir():
    if not file.name.startswith("WT-") and not file.name.startswith("G_") and not file.name.startswith("TN_"):
        probably_renamed.append(file)
print(f"There are {len(probably_renamed)} files that do no start with 'WT-', 'G_' or 'TN_':")
print("")
for i in probably_renamed:
    print(i)
# Out:
# There are 17 files that do no start with 'WT-', 'G_' or 'TN_':
#
# sample_data\AB_2019_7_footwear_import.txt
# sample_data\ab_report_ds135_asbestos.txt
# sample_data\Agreement_on_Safeguards.txt
# sample_data\Copy of Copy of report.txt
# sample_data\Costa Rica - Tariff Schedule (revised) FINAL v3.csv
# sample_data\ds379_china_auto_parts_panel.txt
# sample_data\ds58_shrimp_turtle_AB.txt
# sample_data\final_final_v2.txt
# sample_data\GATT_1994_consolidated.txt
# sample_data\notes_meeting_march.txt
# sample_data\panel report DS412 Canada FIT programme.txt
# sample_data\report(draft)v2.txt
# sample_data\scan0001.txt
# sample_data\tariff_schedule_brazil_2021.csv
# sample_data\Understanding_DSU_consolidated_1994.txt
# sample_data\untitled_document_3.txt
# sample_data\wt_min17_w_8.txt

# %%
# Stretch 2
longest = 0
for filename in data_dir.iterdir():
    length = len(filename.name)
    if length > longest:
        longest = length
        longest_filename = filename

print(f"Longest filename: {longest_filename}, has lenght {longest}.")
# Out:
# Longest filename: sample_data\Costa Rica - Tariff Schedule (revised) FINAL v3.csv, has lenght 51.
