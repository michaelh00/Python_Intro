# %% [markdown]
# # Course roadmap — teacher notebook
#
# **How to use this file.** Keep this notebook open on one screen. On the
# other screen, open a *fresh, empty* notebook and type into that one while
# students watch. Read the teacher-notes here, type the code cell below
# into the student-facing notebook, run it, discuss. Do **not** project
# this file — it contains solutions.
#
# ## Legend
#
# | Tag | Meaning |
# |-----|---------|
# | 🟢 Core     | Must show. Everyone needs it for later. |
# | 🟡 Optional | Show if you're on time. Skip without guilt. |
# | 🔵 Bonus    | Only if a student asks or you're way ahead. |
#
# ## Session map
#
# | Session | Block                          | Cumulative | Content |
# |---------|--------------------------------|-----------:|---------|
# | **2**   | Calculator + `print` + vars    | 10 min     | 🟢 |
# |         | Types + conversions            | 20 min     | 🟢 |
# |         | Comparisons + booleans         | 25 min     | 🟢 |
# |         | **Exercise Block 1**           | 45 min     | 🟢 |
# |         | Strings + f-strings            | 60 min     | 🟢 |
# |         | Lists, sets, dicts             | 80 min     | 🟢 |
# |         | **Exercise Block 2**           | 90 min     | 🟢 (start; finish as HW) |
# | **3**   | `if` / `for` / `while`         | 15 min     | 🟢 |
# |         | Functions                      | 30 min     | 🟢 |
# |         | **Exercise Block 3**           | 45 min     | 🟢 |
# |         | `pathlib`: explore folder      | 60 min     | 🟢 |
# |         | `mkdir`, `shutil`, `write_text`| 75 min     | 🟢 |
# |         | **Capstone** (start)           | 90 min     | 🟢 (finish as HW) |
#
# ## Rules of thumb while teaching
#
# - **Always type, never paste.** Students copy your rhythm, not your code.
# - **Provoke the errors marked below.** Meeting `NameError`, `TypeError`,
#   `SyntaxError` on purpose is worth more than any lecture about them.
# - **When you fall behind:** cut 🟡 first, then compress exercise
#   debrief. Never cut Exercise Block 1 or the capstone.
# - **When a student asks "why?":** answer briefly, offer the 🔵 deep-dive
#   after class. Do not derail the session.
#
# ---

# %% [markdown]
# # Session 2 — Python basics (90 min)
#
# Goal: by the end, every student can read and write Python that uses
# variables, the four everyday types, strings, lists, and dictionaries,
# and knows what a traceback is.
#
# Nothing today touches disk. That's Session 3.
#
# ---

# %% [markdown]
# ## Part 1 — Python as a calculator

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* Open a fresh notebook. Show that a code cell prints its last expression.
#
# *Watch for:* Shift+Enter runs the cell. Ctrl+Enter runs and stays.

# %%
2 + 3

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Rattle through the four basic operators. Don't linger.

# %%
5 - 1

# %%
3 * 4

# %%
10 / 5

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Now the three that surprise people: floor div, modulo, the fact that `/` always returns a float even when it divides evenly.
#
# *Watch for:* `//` is not a comment here. `%` is not percent.

# %%
12 // 5

# %%
12 % 5

# %%
12 / 5

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2 — `print()` and variables

# %% [markdown]
# **🟢 Core · 1 min**
#
# *Say:* First `print`. Explain: strings need quotes.

# %%
print("Hello from the Data Science Lab!")

# %% [markdown]
# **🟢 Core — provoke error · 2 min**
#
# *Say:* Type it without quotes on purpose. Read the SyntaxError together, bottom line first.
#
# *Provoke:* Missing quotes → SyntaxError
#
# *Watch for:* Students read tracebacks top-down. Train them to read bottom-up.

# %%
print(Hello from the Data Science Lab!)

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Introduce assignment. The `=` is a label sticker, not maths.

# %%
country = "Switzerland"
country

# %%
print(country)

# %%
print("I live in", country)

# %% [markdown]
# **🟢 Core — provoke three errors · 4 min**
#
# *Say:* Show each broken name, let the SyntaxError happen, then fix. This is the one time you should type broken code deliberately.
#
# *Provoke:* spaces, leading digit, special char in variable names

# %%
country of interest = "USA"

# %%
country_of_interest = "USA"

# %%
2nd_country = "USA"

# %%
&country = "USA"

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Reassignment. Types can change with reassignment — Python is dynamic.

# %%
my_variable = 25
my_variable

# %%
my_variable = "12"
my_variable

# %%
my_variable_2 = "34"
my_variable_2

# %% [markdown]
# **🟢 Core — the punchline · 3 min**
#
# *Say:* Add two strings vs add two ints. This is the first time students see that `+` means different things depending on type.
#
# *Watch for:* `"12" + "34"` is `"1234"`, not `46`.

# %%
my_variable + my_variable_2

# %%
my_variable_3 = 12
my_variable_3

# %%
my_variable_4 = 34
my_variable_4

# %%
my_variable_3 + my_variable_4

# %% [markdown]
# **🟢 Core — provoke TypeError · 2 min**
#
# *Say:* Now mix a string and an int with `+`. Read the traceback together.
#
# *Provoke:* TypeError: unsupported operand type(s) for +: 'str' and 'int'

# %%
my_variable_2 + my_variable_4

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3 — The four everyday types

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* int, float, str, bool. `type()` is your friend. Show all four.

# %%
integer_type = 316
print(integer_type, "is of type", type(integer_type))

# %%
float_type = 316.0
print(float_type, "is of type", type(float_type))

# %%
string_type = "Hello World"
print(string_type, "is of type", type(string_type))

# %%
bool_type = True
print(bool_type, "is of type", type(bool_type))

# %% [markdown]
# **🟢 Core — provoke TypeError, then fix · 3 min**
#
# *Say:* Classic 'Case number: ' + 316 mistake. Read the error, then fix with str().
#
# *Provoke:* TypeError concatenating str and int
#
# *Watch for:* `str(x)` converts, it does not modify x.

# %%
case_number = 316
message = "Case number: " + case_number

# %%
case_number = 316
message = "Case number: " + str(case_number)
print(message)

# %% [markdown]
# **🟡 Optional · 3 min**
#
# *Say:* int() truncates, round() rounds. Not the same. Show both.
#
# *Watch for:* `int(5.9)` is 5, not 6.

# %%
i = int(5.9)
i

# %%
r = round(5.9)
r

# %%
type(r)

# %% [markdown]
# **🟡 Optional · 1 min**
#
# *Say:* float() from a string, str() from a number. Round-trip.

# %%
f = float("3.14")
f

# %%
s = str(2024)
s

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Comparisons return bool. Double-equals for comparison, single for assign. Write this on the board.
#
# *Watch for:* `=` vs `==` is the #1 beginner bug.

# %%
tariff_rate = 5.5

result = tariff_rate > 10
print(result)

result = tariff_rate < 10
print(result)

result = tariff_rate == 10
print(result)

result = tariff_rate != 10
print(result)

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* Combine with `and` / `or`. English words, not `&&`.

# %%
tariff_rate = 5.5

result = tariff_rate > 10 and tariff_rate < 20
print(result)

result = tariff_rate < 10 or tariff_rate > 20
print(result)

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 1 — Variables and operators
#
# *(20 min. Everyone should finish Core. Stretch if fast. Homework never
# required for the capstone.)*
#
# ### Core (everyone)
#
# 1. Create three variables describing a country: `name` (str),
#    `population_millions` (float), and WTO membership (bool).
# 2. Print a sentence using all three, of the shape
#    `"Kenya has 55.1 million people. Is it member of the WTO? True"`.
#    Use `print()` with commas.
# 3. A document has 142 pages. Using `//` and `%`, compute full chapters
#    of 20 pages, and leftover pages. Print both.
# 4. Given `year_signed = 1994`, compute `age` in 2026. Print it.
#
# ### Stretch
#
# 1. Given `tariff_rate = 7.5` and `discount = 0.20`, print the discounted
#    rate with a message.
# 2. Check whether `population_millions` is between 10 and 100 inclusive.
#    Store in `is_medium_sized`. Print.
# 3. Deliberately trigger a `TypeError`. Read the traceback. Fix.
#
# ### Homework — none for this block.

# %% [markdown]
# **🟢 Core solutions · kept visible for you**
#
# *Say:* Do not project. If a student is stuck, walk over and code with them.

# %%
# Core 1 & 2
name = "Germany"
population_millions = 83.24
member_wto = True
print(name, "has", population_millions, "people. Is it member of the WTO?", member_wto)

# %%
# Core 3
doc_size = 142
chapter_size = 20
num_chapters = doc_size // chapter_size
pages_left = doc_size % chapter_size
print("Number of chapters:", num_chapters)
print("Pages left:", pages_left)

# %%
# Core 4
year_signed = 1994
age = 2024 - year_signed
print("Age since signing:", age)

# %%
# Stretch 1
tariff_rate = 7.5
discount = 0.2
discounted_tariff_rate = tariff_rate * (1 - discount)
print("Discounted tariff rate:", discounted_tariff_rate)

# %%
# Stretch 2
population_millions = 83.24
is_medium_sized = population_millions > 10 and population_millions < 100
print("Population between 10 and 100 millions:", is_medium_sized)

# %% [markdown]
# ---

# %% [markdown]
# ## Part 4 — String manipulations

# %% [markdown]
# **🟢 Core · 5 min**
#
# *Say:* Introduce string methods on a deliberately messy filename. Every method returns a NEW string. The original never changes.
#
# *Watch for:* `.strip()` alone does nothing lasting — you must assign the result.

# %%
filename = "  Costa Rica - Tariff Schedule FINAL.csv  "
filename

# %%
filename.strip()

# %%
filename.lower()

# %%
filename.strip().lower()

# %%
filename.replace(" ", "_")

# %%
filename.endswith(".csv")

# %%
filename.strip().endswith(".csv")

# %%
len(filename)

# %% [markdown]
# **🟢 Core — the point · 2 min**
#
# *Say:* Show that `filename` is unchanged. Then assign the chained result.

# %%
filename

# %%
cleaned = filename.strip().lower().replace(" ", "_")
cleaned

# %% [markdown]
# **🟢 Core · 4 min**
#
# *Say:* Indexing and slicing on a WTO symbol. Positions start at 0. `[a:b]` is up-to-but-not-including b.
#
# *Watch for:* Off-by-one. Students expect [3:6] to include position 6.

# %%
symbol = "WT-DS316-AB-R"

# %%
symbol[0]

# %%
symbol[5]

# %%
symbol[3:6]

# %%
symbol[-1]

# %% [markdown]
# **🟢 Core — provoke TypeError · 3 min**
#
# *Say:* Try to assign to a character. Strings are IMMUTABLE. Read the error.
#
# *Provoke:* TypeError: 'str' object does not support item assignment

# %%
symbol[3] = 'X'
symbol

# %%
var = symbol[3]
var

# %%
symbol = symbol.replace(var, "X")
symbol

# %% [markdown]
# ---

# %% [markdown]
# ## Part 5 — f-strings

# %% [markdown]
# **🟢 Core · 5 min**
#
# *Say:* Show the three ways to build a sentence: commas, +, f-string. Land firmly on f-strings.
#
# *Watch for:* Missing the `f` prefix → `{country}` prints literally.

# %%
country = "Kenya"
tariff_rate = 5.5
year = 2024

# %%
print("In", year, ",", country, "had a tariff rate of", tariff_rate, "%", ".")

# %%
print("In " + str(year) + ", " + country + " had a tariff rate of " + str(tariff_rate) + "%.")

# %%
print(f"In {year}, {country} had a tariff rate of {tariff_rate}%.")

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Format specifiers for decimals.

# %%
tariff_rate = 5.12986

print(f"{tariff_rate}")
print(f"{tariff_rate: .2f}")
print(f"{tariff_rate: .4f}")

# %% [markdown]
# ---

# %% [markdown]
# ## Part 6 — Lists

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Lists hold anything, in order. `len()` for size. Mixed types allowed but usually a smell.

# %%
my_list = [10, 21, 0.512, "Hello"]
print(my_list)
print(len(my_list))

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Indexing and slicing — same rules as strings. Position 0. Half-open range.

# %%
my_list[1]

# %%
my_list[0:3]

# %%
my_list[:3]

# %%
my_list[2:]

# %%
my_short_list = my_list[1:4]
print(my_list)
print(my_short_list)

# %% [markdown]
# **🟢 Core · 4 min**
#
# *Say:* Lists ARE mutable, unlike strings. Show append, pop, replace-by-index, remove, insert.
#
# *Watch for:* `pop(3)` uses an INDEX. `remove('France')` uses a VALUE.

# %%
my_list = [10, 21, 0.512, 'Hello']
my_list

# %%
my_list.append("Switzerland")
my_list

# %%
my_list.pop(3)
my_list

# %%
my_list[1] = "France"
my_list

# %%
my_list.remove("France")
my_list

# %%
my_list.insert(0, "Germany")
my_list

# %% [markdown]
# ---

# %% [markdown]
# ## Part 7 — Sets (briefly)

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Sets keep only unique values. One-liner to dedupe. Move on.

# %%
tariff_rates = [5.0, 7.5, 5.0, 10.0, 7.5, 5.0]

unique_rates = set(tariff_rates)
unique_rates

# %% [markdown]
# ---

# %% [markdown]
# ## Part 8 — Dictionaries

# %% [markdown]
# **🟢 Core · 5 min**
#
# *Say:* Lookup by name instead of position. Introduce with a country record.

# %%
country = {
    "name" : "Kenya",
    "population_millions" : 55.1,
}
country

# %%
country["name"]

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Add a key by assignment. Update with `.update({...})`.

# %%
country["capital"] = "Nairobi"

# %%
country

# %%
country.update({"region": "Africa", "wto_member": True})

# %%
country

# %% [markdown]
# **🟢 Core — the workhorse shape · 4 min**
#
# *Say:* List of dicts. This is what real data looks like. Show two-level indexing: `countries[2]["name"]`.

# %%
country2 = {
'name': 'Germany',
 'population_millions': 83.2,
 'capital': 'Berlin',
 'region': 'Europe',
 'wto_member': True
}

# %%
country3 = {
'name': 'Switzerland',
  'population_millions': 8.6,
  'capital': 'Bern',
  'region': 'Europe',
  'wto_member': True,
}

# %%
countries = [country, country2, country3]
countries

# %%
countries[2]["name"]

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 2 — Strings and containers
#
# *(10 min in class, rest as homework. Time budget is tight — set them
# loose on Core, take questions, wrap the session.)*
#
# ### Core
#
# 1. Clean `raw = "  KENYA - Tariff Schedule 2024.CSV  "` into
#    `"kenya_-_tariff_schedule_2024.csv"` by chaining methods.
# 2. Build a list `un_founders` (≥ 4 countries). Print first, last, length.
# 3. From `symbol = "WT-DS316-AB-R"`, slice out `"DS316"`.
# 4. Make a dict with `name`, `capital`, `population_millions`. Print a
#    sentence with an f-string.
#
# ### Stretch
#
# 1. From `rates = [1.8, 12.0, 13.5, 4.3, 7.5, 9.0, 5.5]`, slice last three
#    and middle three.
# 2. Add `"is_wto_member": True` to your dict, print, then bump population
#    by 1.0 and print again.
# 3. Build a `set` from `rates`. Print how many distinct.
#
# ### Homework (optional)
#
# 1. From `raw = "population: 55.1 million"`, extract `55.1` as a float
#    using slicing.
# 2. Given a `docs` list of dicts, print the `kind` of the first, the
#    `year` of the last, and an f-string identifying the oldest.

# %% [markdown]
# **🟢 Solutions · kept visible for you**
#
# *Say:* Do not project.

# %%
# Core 1
raw = "  KENYA - Tariff Schedule 2024.CSV  "
cleaned = raw.strip().lower().replace(" ", "_")
cleaned

# %%
# Core 2
un_founders = ["United States", "Sowjet Union", "United Kingdom", "France", "China"]
print(un_founders[0])
print(un_founders[-1])
print(len(un_founders))

# %%
# Core 3
symbol = "WT-DS316-AB-R"
symbol[3:8]

# %%
# Core 4
d = {"name": "Brazil", "capital": "Brasília", "population_millions": 213}
print(f"{d['name']} has a population of {d['population_millions']} million and its capital is {d['capital']}.")

# %%
# Stretch 1
rates = [1.8, 12.0, 13.5, 4.3, 7.5, 9.0, 5.5]
print(rates[-3:])
print(rates[2:5])

# %%
# Stretch 2
d["is_wto_member"] = True
print(d)
d["population_millions"] = d["population_millions"] + 1
print(d)

# %%
# Stretch 3
distinct_rates = set(rates)
print(len(distinct_rates))

# %%
# Homework 1
raw = "population: 55.1 million"
str_55 = raw[12:17]
float_55 = float(str_55)
print(float_55)
print(type(float_55))

# %%
# Homework 2
docs = [
    {"filename": "DS316-AB-R.txt", "year": 2011, "kind": "appellate"},
    {"filename": "DS135-panel.txt", "year": 2001, "kind": "panel"},
    {"filename": "gatt_1994.txt", "year": 1994, "kind": "legal"},
    {"filename": "DS58-shrimp-turtle.txt", "year": 1998, "kind": "appellate"},
]
print(docs[0]["kind"])
print(docs[-1]["year"])
print(f"The oldest of these four documents was signed in {docs[2]['year']}.")

# %% [markdown]
# ---
#
# ## End of Session 2
#
# If Core of Block 1 and Block 2 are done, they have every language piece
# they need. Session 3 adds control flow, functions, and applies all of it
# to a folder on disk.

# %% [markdown]
# # Session 3 — Control flow, functions, and the file organiser (90 min)
#
# Goal: `if` / `for` / `while` / `def`, then use them to organise a messy
# folder of WTO documents into tidy subfolders.
#
# **Pace warning.** This session is dense. If you fall behind:
# - Drop the rock-paper-scissors game (🟡).
# - Drop the dice `while`-loop demo (🟡).
# - Never drop the file-organiser capstone start.
#
# **Before class:** run `python setup_sample_data.py` in the terminal so
# `sample_data/` exists.
#
# ---

# %% [markdown]
# ## Part 1 — Decisions with `if`

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Indentation matters. Four spaces. `if` / `elif` / `else`. Categorise a tariff rate.
#
# *Watch for:* Mixed tabs and spaces → IndentationError. Configure editor to spaces.

# %%
tariff_rate = 7.5

if tariff_rate > 10:
    category = "high"
elif tariff_rate > 5:
    category = "moderate"
else:
    category = "low"

print(category)

# %% [markdown]
# **🟡 Optional — rock/paper/scissors · 5 min**
#
# *Say:* Fun demo of chained conditions. Skip if behind schedule.

# %%
import random
choices = ["rock", "paper", "scissors"]
computer_choice = random.choice(choices)

your_choice = "rock"

if your_choice == computer_choice:
    print(f"Both chose {your_choice}. It's a tie!")
elif your_choice == "scissors" and computer_choice == "paper":
    print("You chose scissors and computer chose paper. You win!")
elif your_choice == "paper" and computer_choice == "rock":
    print("You chose paper and computer chose rock. You win!")
elif your_choice == "rock" and computer_choice == "scissors":
    print("You chose rock and computer chose scissors. You win!")
else:
    print(f"You chose {your_choice} and computer chose {computer_choice}. You lose!")

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2 — `for` loops

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Walk through a list. Loop variable takes each value in turn.

# %%
countries = ["Switzerland", "USA", "Brazil", "Kenya"]

for country in countries:
    print(f"Country: {country}")

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* Counter inside a loop. Foreshadows accumulator pattern used in capstone.

# %%
countries = ["Switzerland", "USA", "Brazil", "Kenya"]

count = 0
for country in countries:
    count = count + 1
    print(f"{count} -> {country}")

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* `range(0, 5)` gives 0..4. Half-open again.

# %%
for i in range(0, 5):
    print(i)

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* `enumerate` when you need both index and item. Cleaner than manual counter.

# %%
countries = ["Switzerland", "USA", "Brazil", "Uganda", "Kenya"]

for index, country in enumerate(countries):
    print(f"{index}: {country}")

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Combine `for` and `if`. Then show `break` (stop at first hit) and `continue` (skip this item).

# %%
for index, country in enumerate(countries):
    if country.startswith("U"):
        print(f"Found a country starting with 'U' in the list of countries at index {index}")

# %%
for index, country in enumerate(countries):
    if country.startswith("U"):
        print(f"Found a country starting with 'U' in the list of countries at index {index}")
        break

# %%
for index, country in enumerate(countries):
    if not country.startswith("U"):
        continue
    print(f"Processing country: {country}")

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Loop over a dict with `.items()`.

# %%
country = {"name": "Kenya", "population_millions": 55.1}

for key, value in country.items():
    print(f"{key} -> {value}")

# %% [markdown]
# **🟢 Core — the pattern of the day · 3 min**
#
# *Say:* Loop, decide, accumulate into a new list. This IS the file-organiser pattern, just with countries instead of files.

# %%
countries = [
    {"name": "Switzerland", "avg_tariff": 1.8},
    {"name": "Kenya",       "avg_tariff": 12.0},
    {"name": "Brazil",      "avg_tariff": 13.5},
    {"name": "Japan",       "avg_tariff": 4.3},
]

high_tariff_countries = []

for c in countries:
    if c["avg_tariff"] > 10:
        high_tariff_countries.append(c["name"])

print(high_tariff_countries)

# %% [markdown]
# ---

# %% [markdown]
# ## Part 3 — `while` loops

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Countdown. Emphasise that the loop variable MUST change or you loop forever.
#
# *Watch for:* Forgetting to decrement → infinite loop. Show interrupt button.

# %%
counter = 10
while counter > 0:
    print(counter)
    counter = counter - 1
print("Liftoff!")

# %% [markdown]
# **🟡 Optional — dice · 3 min**
#
# *Say:* Nice `while` example: roll until a 6. Unknown number of iterations. Skip if tight.

# %%
import random
dice_roll = random.randint(1, 6)
dice_roll

# %%
dice = 1
rolls = 0

while dice != 6:
    dice = random.randint(1, 6)
    rolls = rolls + 1
    print(f"Rolled: {dice}")

print(f"You needed {rolls} rolls to get a 6.")

# %% [markdown]
# ---

# %% [markdown]
# ## Part 4 — Functions

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* `def`, no args, no return. Just packaging a print.

# %%
def greet():
    print(f"Welcome to the course.")

greet()

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* Add a parameter. Call twice with different args.

# %%
def greet(name):
    print(f"Welcome to the course, {name}.")

greet("Matteo")
greet("Ana")

# %% [markdown]
# **🟢 Core — the key idea · 3 min**
#
# *Say:* `return` hands a value back. Compare to `print`. A function that only prints is much less useful.
#
# *Watch for:* `return` vs `print` — students conflate them for weeks.

# %%
def calculate_sum(a, b):
    sum = a + b
    return sum

calculate_sum(3, 5)

# %% [markdown]
# **🟡 Optional — dice function · 3 min**
#
# *Say:* Wrapping the while-loop into a function that takes `sides` as a parameter. Nice composition example. Skip if very tight.

# %%
import random

def roll_until_six(sides):
    dice = 1
    rolls = 0
    while dice != 6:
        dice = random.randint(1, sides)
        rolls = rolls + 1
    return rolls

dices = {"cube": 6, "octahedron": 8, "dodecahedron": 12, "icosahedron": 20}

for name, sides in dices.items():
    print(f"{name.capitalize()} needed {roll_until_six(sides)} rolls to get a 6.")

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* Functions calling functions. Small pieces composed. This is exactly the shape of the file organiser we'll write in an hour.

# %%
def convert_to_chf(amount, rate):
    return amount * rate

def print_price(amount, currency, rate):
    chf = convert_to_chf(amount, rate)
    print(f"{amount} {currency} = {chf} CHF")

print_price(100, "USD", 0.88)
print_price(50, "EUR", 0.95)

# %% [markdown]
# ---

# %% [markdown]
# ## Exercise Block 3 — Decisions, loops, functions
#
# *(15 min. Tight. Set them loose, walk the room, debrief briefly.)*
#
# Use throughout:
#
# ```python
# countries = [
#     {"name": "Switzerland", "population_millions": 8.8,   "avg_tariff": 1.8,  "wto_member": True},
#     {"name": "Kenya",       "population_millions": 55.1,  "avg_tariff": 12.0, "wto_member": True},
#     {"name": "Brazil",      "population_millions": 214.3, "avg_tariff": 13.5, "wto_member": True},
#     {"name": "Japan",       "population_millions": 125.7, "avg_tariff": 4.3,  "wto_member": True},
#     {"name": "Argentina",   "population_millions": 45.4,  "avg_tariff": 13.6, "wto_member": True},
#     {"name": "Iran",        "population_millions": 88.6,  "avg_tariff": 20.1, "wto_member": False},
# ]
# ```
#
# ### Core
#
# 1. Loop and print each name.
# 2. Loop and print `"<name>: high tariff"` only for `avg_tariff > 10`.
# 3. Function `is_populous(country, threshold=50)` returning bool. Test twice.
# 4. Count WTO members with a `for` + `if`. Print the count.
#
# ### Stretch
#
# 1. Build `wto_only` list with only WTO-member dicts. Print its length.

# %% [markdown]
# **🟢 Solutions · kept visible for you**
#
# *Say:* Do not project.

# %%
countries = [
    {"name": "Switzerland", "population_millions": 8.8,   "avg_tariff": 1.8,  "wto_member": True},
    {"name": "Kenya",       "population_millions": 55.1,  "avg_tariff": 12.0, "wto_member": True},
    {"name": "Brazil",      "population_millions": 214.3, "avg_tariff": 13.5, "wto_member": True},
    {"name": "Japan",       "population_millions": 125.7, "avg_tariff": 4.3,  "wto_member": True},
    {"name": "Argentina",   "population_millions": 45.4,  "avg_tariff": 13.6, "wto_member": True},
    {"name": "Iran",        "population_millions": 88.6,  "avg_tariff": 20.1, "wto_member": False},
]

# %%
# Core 1
for c in countries:
    print(c["name"])

# %%
# Core 2
for c in countries:
    country_tariff = c["avg_tariff"]
    if country_tariff > 10:
        print(f"{c['name']}: high tariff")

# %%
# Core 3
def is_populous(contry, threshold=50):
    if contry["population_millions"] > threshold:
        return True
    else:
        return False
print(is_populous(countries[0]))
print(is_populous(countries[2]))

# %%
# Core 4
wto_member = 0
for country in countries:
    if country["wto_member"] == True:
        wto_member = wto_member + 1
print(wto_member)

# %%
# Stretch 1
wto_only = []
for country in countries:
    if country["wto_member"] == True:
        wto_only.append(country)
print(len(wto_only))

# %% [markdown]
# ---

# %% [markdown]
# ## Part 5 — Exploring a folder with `pathlib`
#
# We're now applying every pattern from the last hour — loops, ifs,
# dictionaries, functions — to a real folder on disk. Nothing about the
# language is new. Only the objects (`Path`) are.
#
# **Check first:** run the next cell. If it fails, run
# `python setup_sample_data.py` in the terminal.

# %% [markdown]
# **🟢 Core — safety check · 1 min**
#
# *Say:* If sample_data/ isn't there, stop and run the setup script in the terminal.
#
# *Provoke:* FileNotFoundError → tells students exactly what to do

# %%
from pathlib import Path

data_dir = Path("sample_data")

if not data_dir.exists():
    raise FileNotFoundError(
        "sample_data/ not found — run 'python setup_sample_data.py' in the terminal, then re-run this cell."
    )

files = list(data_dir.iterdir())
print(f"Found {len(files)} files in {data_dir.resolve()}")

# %% [markdown]
# **🟢 Core · 1 min**
#
# *Say:* Peek at the mess so students see why organising is worth doing.

# %%
for f in files[:8]:
    print(f.name)

# %% [markdown]
# **🟢 Core · 4 min**
#
# *Say:* A `Path` is an object. The `/` operator joins path parts — no manual slashes, no OS-specific bugs. Show what a Path knows about itself.
#
# *Watch for:* Path is not a string. `.name`, `.stem`, `.suffix` are attributes/props.

# %%
from pathlib import Path

p = Path("sample_data") / "WT-DS316-AB-R.txt"
print(p)

# %%
p = Path("sample_data") / "WT-DS316-AB-R.txt"

print("full path :", p)
print("name      :", p.name)     # WT-DS316-AB-R.txt
print("stem      :", p.stem)     # WT-DS316-AB-R
print("suffix    :", p.suffix)   # .txt
print("parent    :", p.parent)   # sample_data
print("exists    :", p.exists())

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* `iterdir()` gives one Path per entry. Combine with `for` + `if` + counter — exactly the pattern from Exercise Block 3.

# %%
data_dir = Path("sample_data")

for f in data_dir.iterdir():
    print(f.name)

# %%
count_csv = 0

for f in data_dir.iterdir():
    if f.suffix == ".csv":
        count_csv = count_csv + 1

print(f"{count_csv} CSV files")

# %% [markdown]
# **🟢 Core · 3 min**
#
# *Say:* `.name` is a string — all Session-2 string methods still work. This is the payoff: yesterday's toys, today's work.

# %%
for f in data_dir.iterdir():
    if "asbestos" in f.name.lower():
        print(f.name)

# %%
official_looking = []

for f in data_dir.iterdir():
    name = f.name
    if name.startswith("WT-") or name.startswith("G_") or name.startswith("TN_"):
        official_looking.append(name)

print(len(official_looking), "files look officially named")
for n in official_looking[:5]:
    print("  ", n)

# %% [markdown]
# **🟢 Core — accumulator into dict · 3 min**
#
# *Say:* Counting by category into a dict. THIS is the pattern the capstone needs. Show both the long form and `.get(key, default)`.

# %%
counts = {}

for f in data_dir.iterdir():
    suffix = f.suffix
    if suffix in counts:
        counts[suffix] = counts[suffix] + 1
    else:
        counts[suffix] = 1

print(counts)

# %%
counts = {}

for f in data_dir.iterdir():
    counts[f.suffix] = counts.get(f.suffix, 0) + 1

print(counts)

# %% [markdown]
# **🟡 Optional · 1 min**
#
# *Say:* `glob` is a shortcut when you just want a pattern match. Skip if tight.

# %%
csvs = list(data_dir.glob("*.csv"))
print(len(csvs), "CSV files")

for c in csvs:
    print(" ", c.name)

# %% [markdown]
# ---

# %% [markdown]
# ## Part 6 — Making folders, copying, writing files
#
# Now we change disk. Only ever write into new folders we create ourselves.
# Never touch `sample_data/`. If anything breaks, rerun the setup script.

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* `mkdir(parents=True, exist_ok=True)` = safe 'make sure this exists'.
#
# *Watch for:* Without `exist_ok=True`, second run raises FileExistsError.

# %%
target = Path("organised") / "appellate_body"
target.mkdir(parents=True, exist_ok=True)

print(target.exists())

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* `shutil.copy(src, dst)`. Destination folder must already exist — that's what mkdir was for.

# %%
import shutil

source = Path("sample_data") / "WT-DS316-AB-R.txt"
destination = Path("organised") / "appellate_body" / source.name

shutil.copy(source, destination)
print(destination.exists())

# %% [markdown]
# **🟡 Optional · 2 min**
#
# *Say:* Renaming with `.rename`. Skip unless a student asks.

# %%
old = destination
new = destination.with_name("renamed_example.txt")

old.rename(new)

print("old exists?", old.exists())
print("new exists?", new.exists())

# %% [markdown]
# **🟢 Core · 2 min**
#
# *Say:* `write_text` writes a whole string, overwriting. `read_text` reads it back. This is how the capstone will produce a summary.txt.

# %%
report = Path("organised") / "summary.txt"

report.write_text(
    "Organisation summary\n"
    "--------------------\n"
    "Files handled so far: 1\n"
)

print("wrote", report)

# %%
content = report.read_text()
print(content)

# %% [markdown]
# **🟢 Core — THE moment · 5 min**
#
# *Say:* Everything comes together. A function that classifies a filename. A loop that classifies, mkdirs, copies. Walk through it slowly. This is the whole point of the course.
#
# *Watch for:* `classify` uses `if / elif` order — first match wins. Order matters.

# %%
def classify(filename):
    name = filename.lower()
    if "ab" in name and "ds" in name:
        return "appellate_body"
    elif "panel" in name:
        return "panel_report"
    elif name.endswith(".csv") or "tariff" in name:
        return "tariff_schedule"
    elif "min" in name or name.startswith("tn_"):
        return "ministerial"
    elif "agreement" in name or "understanding" in name or "gatt" in name:
        return "legal_text"
    else:
        return "unclassified"


out_root = Path("organised_demo")

for f in data_dir.iterdir():
    category = classify(f.name)
    dest_folder = out_root / category
    dest_folder.mkdir(parents=True, exist_ok=True)
    shutil.copy(f, dest_folder / f.name)

print("done. contents of organised_demo/:")
for sub in out_root.iterdir():
    n = len(list(sub.iterdir()))
    print(f"  {sub.name}: {n} files")

# %% [markdown]
# ---

# %% [markdown]
# ## Capstone — Your own organiser
#
# *(15 min in class to start, finish as homework.)*
#
# **Safety:** only write to new folders (`my_organised/`), never into
# `sample_data/`. If anything breaks, rerun the setup script.
#
# ### Core (start in class)
#
# 1. Create `my_organised/` next to this notebook.
# 2. Inside it, create `csv_files/` and `txt_files/`.
# 3. Loop through `sample_data/`. Copy every `.csv` into `csv_files/`,
#    every `.txt` into `txt_files/`. Skip everything else.
# 4. Print how many files ended up in each subfolder using `.iterdir()`
#    and a counter.
#
# ### Stretch (homework — real summary)
#
# 1. Reuse the `classify` function. Sort by all six categories.
# 2. Keep a running dict `counts` inside the loop.
# 3. Write `my_organised/summary.txt` with one line per category and a
#    `total:` line. Read it back and print.
#
# ### Homework (optional — collisions)
#
# 1. Handle the two shrimp-turtle duplicates: if a file with the same
#    case-number prefix is already in the target folder, append `_dup`
#    to the stem instead of overwriting.
# 2. Add a duplicates section to the summary.
# 3. Wrap everything in `organise(source_folder, target_folder)` that
#    returns the counts dict.
#
# ---
#
# ## Wrap-up
#
# **Say to the class:** "You've written a script that would take an
# afternoon by hand. For 100 files or 10 000 files, it's the same amount
# of typing. The pattern — *loop over a folder, decide, act, record* — is
# the shape of a huge fraction of research automation. Swap in interview
# transcripts, court PDFs, scraped articles: same scaffolding."

# %% [markdown]
# **🟢 Core capstone solution · kept visible for you**
#
# *Say:* Do not project. If a student is stuck at minute 10, walk over.

# %%
from pathlib import Path
import shutil

data_dir = Path("sample_data")
out = Path("my_organised")

(out / "csv_files").mkdir(parents=True, exist_ok=True)
(out / "txt_files").mkdir(parents=True, exist_ok=True)

for f in data_dir.iterdir():
    if f.suffix == ".csv":
        shutil.copy(f, out / "csv_files" / f.name)
    elif f.suffix == ".txt":
        shutil.copy(f, out / "txt_files" / f.name)

n_csv = 0
for f in (out / "csv_files").iterdir():
    n_csv = n_csv + 1

n_txt = 0
for f in (out / "txt_files").iterdir():
    n_txt = n_txt + 1

print(f"csv_files: {n_csv}")
print(f"txt_files: {n_txt}")

# %% [markdown]
# *End of roadmap.*
